# %% [markdown]
# # Mobile price prediction based on their specifications

# %% [markdown]
# # LinearRegression model

# %%
#importing all necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import warnings
warnings.filterwarnings("ignore")

# %%
Description:-
    
    Features:

fc=field communication
four_g =4G or not
m_dep = mobile depth in cm
sc_h =synchoronization
pc= processsor

# %%
#Reading the csv file....
d1=pd.read_csv(r"C:\Users\saimo\Desktop\tefoLogic_Training_1\5_Projects\Mobile_price_prediction_project_1\mobile_price.csv")

# %%
#finding first 5 rows
d1.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
#below 5 rows
d1.tail(5)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [5 rows x 21 columns]

# %%
#finding rows & columns
d1.shape
# Out:
# (2000, 21)

# %%
list(d1)
# Out:
# ['battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
#Statistical information
d1.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
#finding datatypes
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
#finding unique values
d1.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
#Finding null values
d1.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
#grouping single column
A=d1.groupby(['battery_power']).count()
A
# Out:
#                blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# battery_power
# 501               2            2         2   2       2           2      2
# 502               2            2         2   2       2           2      2
# 503               3            3         3   3       3           3      3
# 504               5            5         5   5       5           5      5
# 506               1            1         1   1       1           1      1
# ...             ...          ...       ...  ..     ...         ...    ...
# 1994              3            3         3   3       3           3      3
# 1995              2            2         2   2       2           2      2
# 1996              2            2         2   2       2           2      2
# 1997              1            1         1   1       1           1      1
# 1998              1            1         1   1       1           1      1
#
#                mobile_wt  n_cores  pc  px_height  px_width  ram  sc_h  sc_w  \
# battery_power
# 501                    2        2   2          2         2    2     2     2
# 502                    2        2   2          2         2    2     2     2
# 503                    3        3   3          3         3    3     3     3
# 504                    5        5   5          5         5    5     5     5
# 506                    1        1   1          1         1    1     1     1
# ...                  ...      ...  ..        ...       ...  ...   ...   ...
# 1994                   3        3   3          3         3    3     3     3
# 1995                   2        2   2          2         2    2     2     2
# 1996                   2        2   2          2         2    2     2     2
# 1997                   1        1   1          1         1    1     1     1
# 1998                   1        1   1          1         1    1     1     1
#
#                talk_time  three_g  touch_screen  wifi  price_range
# battery_power
# 501                    2        2             2     2            2
# 502                    2        2             2     2            2
# 503                    3        3             3     3            3
# 504                    5        5             5     5            5
# 506                    1        1             1     1            1
# ...                  ...      ...           ...   ...          ...
# 1994                   3        3             3     3            3
# 1995                   2        2             2     2            2
# 1996                   2        2             2     2            2
# 1997                   1        1             1     1            1
# 1998                   1        1             1     1            1
#
# [1094 rows x 20 columns]

# %%
B=d1.groupby(['touch_screen']).count()
B
# Out:
#               battery_power  blue  clock_speed  dual_sim    fc  four_g  \
# touch_screen
# 0                       994   994          994       994   994     994
# 1                      1006  1006         1006      1006  1006    1006
#
#               int_memory  m_dep  mobile_wt  n_cores    pc  px_height  \
# touch_screen
# 0                    994    994        994      994   994        994
# 1                   1006   1006       1006     1006  1006       1006
#
#               px_width   ram  sc_h  sc_w  talk_time  three_g  wifi  \
# touch_screen
# 0                  994   994   994   994        994      994   994
# 1                 1006  1006  1006  1006       1006     1006  1006
#
#               price_range
# touch_screen
# 0                     994
# 1                    1006

# %% [markdown]
# # data visualization

# %% [markdown]
# # Histogram ploting

# %%
import matplotlib.pyplot as plt
plt.hist(d1['dual_sim'])
plt.show()

# %% [markdown]
# # piechart

# %%
labels= ['Supported 3G', ' Not-Supported']
values=d1['three_g'].value_counts().values

# %%
plt.axis('equal')
plt.pie(values, labels=labels,autopct='%0.00f%%', explode=[0.1,0], shadow=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
labels= ['with touch screen', ' without touch screen']
values=d1['touch_screen'].value_counts().values

plt.axis('equal')
plt.pie(values, labels=labels,autopct='%0.00f%%', explode=[0.1,0], shadow=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
d1['price_range'].unique()

#0k, 10k,20k,30k
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
# visulization
import matplotlib.pyplot as plt
plt.hist(d1['price_range'])
plt.show()

# %% [markdown]
# # data cleaning

# %%
d2=d1.drop([
 'blue',
 'clock_speed',
 'fc',
 'int_memory',
 'm_dep',
 'n_cores',
 'px_height',
 'px_width',
 'sc_h',
 'sc_w',
 'talk_time',],axis=1)
d2
# Out:
#       battery_power  dual_sim  four_g  mobile_wt  pc   ram  three_g  \
# 0               842         0       0        188   2  2549        0
# 1              1021         1       1        136   6  2631        1
# 2               563         1       1        145   6  2603        1
# 3               615         0       0        131   9  2769        1
# 4              1821         0       1        141  14  1411        1
# ...             ...       ...     ...        ...  ..   ...      ...
# 1995            794         1       1        106  14   668        1
# 1996           1965         1       0        187   3  2032        1
# 1997           1911         1       1        108   3  3057        1
# 1998           1512         0       1        145   5   869        1
# 1999            510         1       1        168  16  3919        1
#
#       touch_screen  wifi  price_range
# 0                0     1            1
# 1                1     0            2
# 2                1     0            2
# 3                0     0            2
# 4                1     0            1
# ...            ...   ...          ...
# 1995             1     0            0
# 1996             1     1            2
# 1997             1     0            3
# 1998             1     1            0
# 1999             1     1            3
#
# [2000 rows x 10 columns]

# %%
#Removing the target variable 
y=d2["price_range"] #target var,dependent variable
x=d2.drop(["price_range"],axis=1) #features,independent variable

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
x
# Out:
#       battery_power  dual_sim  four_g  mobile_wt  pc   ram  three_g  \
# 0               842         0       0        188   2  2549        0
# 1              1021         1       1        136   6  2631        1
# 2               563         1       1        145   6  2603        1
# 3               615         0       0        131   9  2769        1
# 4              1821         0       1        141  14  1411        1
# ...             ...       ...     ...        ...  ..   ...      ...
# 1995            794         1       1        106  14   668        1
# 1996           1965         1       0        187   3  2032        1
# 1997           1911         1       1        108   3  3057        1
# 1998           1512         0       1        145   5   869        1
# 1999            510         1       1        168  16  3919        1
#
#       touch_screen  wifi
# 0                0     1
# 1                1     0
# 2                1     0
# 3                0     0
# 4                1     0
# ...            ...   ...
# 1995             1     0
# 1996             1     1
# 1997             1     0
# 1998             1     1
# 1999             1     1
#
# [2000 rows x 9 columns]

# %% [markdown]
# # split the data into 2 types

# %%
#train = 67 %
#test  = 33 %
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
x_train.shape
# Out:
# (1340, 9)

# %%
y_train.shape
# Out:
# (1340,)

# %%
x_test.shape
# Out:
# (660, 9)

# %%
y_test.shape
# Out:
# (660,)

# %% [markdown]
# # LinearRegression model

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# checking 
n=reg.predict([[842,0,0,188,2,2549,0,0,1]])
n
# Out:
# array([1.63373453])

# %%
a=reg.predict(x_test)
a
# Out:
# array([ 2.67449160e-01,  4.85811274e-01,  1.01162466e+00,  3.85695664e-01,
#         2.46997240e+00,  1.34616578e+00,  3.49405733e-01,  2.14652220e+00,
#         1.73804847e+00,  3.55294718e+00,  1.02315281e-01,  3.20215816e+00,
#         1.07437023e+00,  8.63281417e-01,  2.52738561e+00, -1.36382049e-01,
#         4.02488901e-01,  1.22687735e+00,  1.13141931e+00,  1.74600602e+00,
#         3.07136848e+00,  2.84275191e+00,  8.26390810e-01,  1.90733652e+00,
#         3.04281578e+00,  1.58048251e+00,  1.95867152e+00,  2.02448815e+00,
#         1.42694142e+00,  1.90177867e+00,  1.80357963e+00,  6.65038827e-01,
#         2.30586788e+00, -2.12108901e-01,  3.49472015e+00,  2.50087419e+00,
#         2.97553568e-01,  6.91146188e-02,  7.81412666e-01,  4.97782607e-01,
#         1.17123583e+00,  6.55297159e-01,  2.23052988e+00,  1.02301144e+00,
#        -1.18613788e-01,  6.84485791e-01,  2.42353103e+00,  1.89387177e+00,
#         1.46352130e+00,  2.34915570e+00,  1.69995966e+00,  2.63445686e+00,
#         9.70497765e-01,  2.99237778e+00,  1.61729201e+00,  3.09486590e+00,
#         1.44676630e+00,  2.51508200e+00,  2.57281418e+00,  1.05895917e+00,
#        -2.46819953e-01,  2.09927949e+00,  9.57353116e-01,  2.65721370e+00,
#         1.80924422e+00,  1.35334937e+00,  6.59530994e-01,  1.72882435e+00,
#         2.42271706e+00,  2.05284269e+00,  1.07136829e+00,  1.65450580e+00,
#        -6.94176975e-02,  2.13063001e+00,  2.94363057e+00,  5.85065943e-01,
#         1.62170812e+00,  1.44528677e+00,  5.84319250e-01, -2.90066028e-01,
#         2.61236223e-02,  3.28899891e+00,  1.36688493e+00,  2.00274204e+00,
#         2.56363764e+00,  2.06945625e+00,  2.45447841e+00,  3.22500478e-01,
#         1.23242506e+00,  7.51485576e-01,  2.54934633e+00, -2.68005588e-01,
#         8.67522560e-01,  1.18013752e+00,  1.43957195e+00,  2.47203562e+00,
#         2.80353796e+00, -9.98404870e-02,  2.01234509e+00,  2.43040137e+00,
#         3.03621453e+00,  2.26901702e+00,  6.96470096e-01,  1.51699912e+00,
#         2.01002732e+00,  5.46577025e-01,  5.87130121e-01,  1.19270770e+00,
#         2.30701300e+00,  5.61056282e-01,  1.11585975e+00,  2.13075254e+00,
#         3.09893596e+00,  2.27551998e+00,  1.02767911e+00,  1.30585820e+00,
#         1.66223442e-01,  1.02460332e+00,  9.38506904e-01, -2.71938121e-01,
#         1.35591418e-01,  1.78338549e+00,  2.67019149e+00,  1.67606484e+00,
#         1.15638292e+00,  1.98544550e+00,  2.91016223e+00,  5.32899419e-01,
#         8.28107784e-01,  3.33878117e+00,  1.50378289e+00,  2.06829479e+00,
#         1.57514353e+00, -3.42012700e-01,  2.77057455e+00,  1.20405396e+00,
#         2.04261852e+00, -8.14031979e-02,  1.90672292e+00,  2.58819320e+00,
#         3.25264607e+00,  1.87127282e+00,  2.16213266e+00,  2.41242716e+00,
#         2.07673110e+00,  1.59136686e+00,  2.25434826e-01,  1.14787668e+00,
#         4.46126021e-01,  2.28597511e+00,  2.15046899e+00,  1.54165309e+00,
#         2.61975715e+00, -1.36262895e-01,  1.72122155e+00,  2.97675908e+00,
#         8.47678361e-01,  4.47357047e-01,  1.69526681e+00,  2.02292959e+00,
#         1.13345967e-01,  1.51235657e+00,  2.01896664e+00,  1.59053985e+00,
#         6.96308334e-01,  2.67923036e+00,  2.15073619e+00,  1.71936637e+00,
#         3.06517544e+00, -3.90959165e-02,  1.82951865e+00,  2.66861281e-01,
#         1.63983432e+00,  1.47147544e+00,  2.95713563e+00,  3.16949668e+00,
#         7.53984026e-01,  6.93035918e-01,  3.53444931e-01,  1.05381658e+00,
#         9.29777945e-01,  2.53149316e+00,  1.94163636e+00,  1.87677806e+00,
#         5.01556047e-01,  3.27830350e+00,  1.15149706e+00,  2.03053485e-01,
#         2.30871551e+00,  2.69749341e+00,  1.17484546e+00,  2.63279878e+00,
#         1.11463650e+00,  1.94369651e+00,  1.21113583e+00,  1.09273966e+00,
#         1.64923588e+00,  2.79283273e+00, -1.38545918e-01,  3.01225683e+00,
#         1.24543041e+00,  1.86049328e+00,  9.55525026e-01,  1.52529768e+00,
#         3.13352952e+00,  3.03466525e+00,  5.31250193e-01, -1.08626249e-01,
#         4.50520714e-01,  8.77713774e-01,  9.20613329e-01,  2.18999339e+00,
#         7.94493155e-01,  1.50224336e+00, -3.07237105e-01,  1.06522135e+00,
#         2.81394689e-01,  1.29321351e+00,  2.59216536e+00,  1.98517832e+00,
#        -3.10545190e-01,  1.77097063e+00,  3.49723269e+00,  1.18634723e+00,
#         2.12410066e+00,  5.71410002e-01,  1.95470615e+00,  8.36513210e-01,
#         2.26674235e-01,  2.44956670e+00,  6.45249559e-01,  4.09287764e-02,
#         1.72979613e+00,  3.11455012e+00,  1.54130111e+00,  1.06143437e+00])

# %%
a.shape
# Out:
# (660,)

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import r2_score
r2_score(y_test,a)
# Out:
# 0.8689304755436347

# %% [markdown]
# # mean_squared_error

# %%
from sklearn.metrics import mean_squared_error  #calculating MSE
mean_squared_error(a,y_test)
# Out:
# 0.15529271315433424
